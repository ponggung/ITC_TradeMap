# %%
import pandas as pd
import json

# %%
df = pd.read_pickle('./pickle/df_all.pickle')
df.sample(20)
# Out:
#      country_a                        country_b item_no      date  ex_val  \
# 182      world                            China  020714  2017-M06     0.0
# 1484     world                         Slovakia  020714  2018-M06     0.0
# 881      world                          Bahrain  020714  2018-M03     0.0
# 1111     world                          Germany  020714  2018-M03     0.0
# 32       world                        Argentina  020711  2017-M06     0.0
# 958      world                          Morocco  020711  2018-M10     0.0
# 1527     world                        Swaziland  020714  2018-M09     0.0
# 1637     world                           Guinea  020714  2017-M11     0.0
# 546      world                           Sweden  020711  2017-M10     0.0
# 728      world                          Croatia  020711  2018-M10     0.0
# 786      world                             Fiji  020712  2018-M08     0.0
# 307      world                           France  020714  2017-M11     0.0
# ...

# %%
with open("map_result.json") as file:
    jsonData = json.load(file)
jsonData
# Out:
# {'filters': {'年份': [],
#   '產品項目': [['020711', '020711 生鮮/冷藏的整隻家禽'],
#    ['020712', '020712 生鮮/冷藏的家禽肉塊及雜碎'],
#    ['020714', '020714 冷凍肉塊及雜碎(雞)'],
#    ['040700', '040700 生鮮/冷藏/可保存的禽蛋']],
#   '貿易資訊': [['ex_qty', '出口量(KG)'],
#    ['im_qty', '進口量(KG)'],
#    ['ex_val', '出口值(US dollar)'],
#    ['im_val', '進口值(US dollar)']]},
#  'values': {'020711-2017-M04-ex_qty': {'中國': 5034536,
#    '丹麥': 43544,
#    '俄羅斯': 2093865,
#    '保加利亞': 803765,
#    '克羅埃西亞': 58967,
#    '加拿大': 151376,
#    '匈牙利': 236775,
#    '南非': 44855,
#    '土耳其': 202327,
#    '塞爾維亞': 146663,
#    '奧地利': 893576,
#    '希臘': 547939,
#    '德國': 749334,
#    '愛沙尼亞': 25401,
#    '拉脫維亞': 101604,
#    '挪威': 4960,
#    '捷克': 244939,
#    '斯洛伐克': 113398,
#    '斯洛維尼亞': 148778,
#    '比利時': 3074449,
#    '法國': 1468851,
#    '波士尼亞與赫塞哥維納': 25231,
#    '波蘭': 5696212,
#    '泰國': 9500,
#    '澳大利亞': 6285,
#    '盧森堡': 3628,
#    '立陶宛': 296649,
#    '紐西蘭': 1448,
#    '羅馬尼亞': 332936,
#    '美國': 2770127,
#    '義大利': 1188412,
#    '肯亞': 213,
# ...
